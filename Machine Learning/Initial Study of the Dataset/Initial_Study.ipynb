# %% [markdown]
# ##Import of Libraries

# %%
import pandas as pd

# %% [markdown]
# ##Initial Study of the Dataset

# %%
titanic=pd.read_csv('titanic.csv')
pd.set_option('display.max_rows',None) #to show all the rows instead of ... and then the last ones, if none then we can flexibly change the number fo rows in pd.head(), we can have a particular number as well instead of None

# %%
titanic.head() #shows the first five instances of the dataset
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic.shape #(no.of rows,no.of columns)
# Out:
# (1309, 14)

# %%
titanic.head(300)
# Out:
#      pclass  survived                                               name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 1         1         1                     Allison, Master. Hudson Trevor
# 2         1         0                       Allison, Miss. Helen Loraine
# 3         1         0               Allison, Mr. Hudson Joshua Creighton
# 4         1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5         1         1                                Anderson, Mr. Harry
# 6         1         1                  Andrews, Miss. Kornelia Theodosia
# 7         1         0                             Andrews, Mr. Thomas Jr
# 8         1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9         1         0                            Artagaveytia, Mr. Ramon
# 10        1         0                             Astor, Col. John Jacob
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
titanic.describe() # gives summary of only numeric columns
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
titanic.describe(include="all")#gives summary of all the columns
# Out:
#              pclass     survived              name   sex          age  \
# count   1309.000000  1309.000000              1309  1309  1046.000000
# unique          NaN          NaN              1307     2          NaN
# top             NaN          NaN  Kelly, Mr. James  male          NaN
# freq            NaN          NaN                 2   843          NaN
# mean       2.294882     0.381971               NaN   NaN    29.881135
# std        0.837836     0.486055               NaN   NaN    14.413500
# min        1.000000     0.000000               NaN   NaN     0.166700
# 25%        2.000000     0.000000               NaN   NaN    21.000000
# 50%        3.000000     0.000000               NaN   NaN    28.000000
# 75%        3.000000     1.000000               NaN   NaN    39.000000
# max        3.000000     1.000000               NaN   NaN    80.000000
#
#               sibsp        parch    ticket         fare        cabin embarked  \
# ...

# %%
titanic.describe(include="all").T #to transpose the table
# Out:
#             count unique               top freq        mean        std  \
# pclass     1309.0    NaN               NaN  NaN    2.294882   0.837836
# survived   1309.0    NaN               NaN  NaN    0.381971   0.486055
# name         1309   1307  Kelly, Mr. James    2         NaN        NaN
# sex          1309      2              male  843         NaN        NaN
# age        1046.0    NaN               NaN  NaN   29.881135    14.4135
# sibsp      1309.0    NaN               NaN  NaN    0.498854   1.041658
# parch      1309.0    NaN               NaN  NaN    0.385027    0.86556
# ticket       1309    929          CA. 2343   11         NaN        NaN
# fare       1308.0    NaN               NaN  NaN   33.295479  51.758668
# cabin         295    186       C23 C25 C27    6         NaN        NaN
# embarked     1307      3                 S  914         NaN        NaN
# boat          486     27                13   39         NaN        NaN
# ...

# %% [markdown]
# We can eliminate those vaiables that will not serve the objective task, for example variables that are identifiers
#
# We have the following identifiers: cabin,name,ticket,boat,body,home,dest

# %%
titanic.drop(columns=['cabin','name','ticket','boat','body','home.dest'],inplace=True)
#if inplace=False it return a copy. Otherwise,does operation in place and return None

# %%
titanic.head()
# Out:
#    pclass  survived     sex      age  sibsp  parch      fare embarked
# 0       1         1  female  29.0000      0      0  211.3375        S
# 1       1         1    male   0.9167      1      2  151.5500        S
# 2       1         0  female   2.0000      1      2  151.5500        S
# 3       1         0    male  30.0000      1      2  151.5500        S
# 4       1         0  female  25.0000      1      2  151.5500        S

# %% [markdown]
# We can see what values there are in the categorical variables

# %%
titanic.embarked.unique() #to find all the distinct values present in that column
# Out:
# array(['female', 'male'], dtype=object)

# %%
titanic.sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %% [markdown]
# We will reorder the columns so that the response variable (survival) is first

# %%
cols=list(titanic.columns)
cols.remove('survived')
cols.insert(0,'survived')
titanic=titanic.reindex(columns=cols) #to reorder the columns in the DataFrame based in the new list order

titanic.head()
# Out:
#    survived  pclass     sex      age  sibsp  parch      fare embarked
# 0         1       1  female  29.0000      0      0  211.3375        S
# 1         1       1    male   0.9167      1      2  151.5500        S
# 2         0       1  female   2.0000      1      2  151.5500        S
# 3         0       1    male  30.0000      1      2  151.5500        S
# 4         0       1  female  25.0000      1      2  151.5500        S
